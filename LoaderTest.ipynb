# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from utils import PrimusPreprocessor
from loader import DatasetLoader

# %%
# Use in jupiter notebook to change cells width :)

# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:70% !important; }</style>"))

# %%
data_path = '/home/mateusz/Desktop/7SEM/THESIS/primus'
package_aa = os.path.join(data_path, 'package_aa')
package_ab = os.path.join(data_path, 'package_ab')

# %%
#Firstly extract png and mei files from dataset. It will modify dataset structure and remove redundant files.

# primus = PrimusPreprocessor(data_path)
# primus.extract_data()

# %%
loader = DatasetLoader(package_aa, 'train', 32)

# %%
batch = loader.__getitem__(0) #gets first batch of data
batch_item = 1
img, mei = batch[0][batch_item], batch[1][batch_item]

# %%
plt.figure(figsize=(16,9))
plt.imshow(img, cmap='gray')

# %%
print(mei)
# Out:
# <score>
#  <scoreDef key.sig="1s" meter.sym="common" xml:id="scoredef-0000000210604663">
#   <staffGrp xml:id="staffgrp-0000001019944016">
#    <staffDef clef.line="2" clef.shape="G" lines="5" n="1" xml:id="staffdef-0000000984606558"/>
#   </staffGrp>
#  </scoreDef>
#  <section xml:id="section-0000001390241561">
#   <measure right="single" xml:id="measure-0000001972770236">
#    <staff n="1" xml:id="staff-0000001167836367">
#     <layer n="1" xml:id="layer-0000001838772518">
#      <beam xml:id="beam-0000001967439339">
#       <note dur="8" oct="5" pname="g" xml:id="note-0000001960029696"/>
#       <note dur="16" oct="5" pname="a" xml:id="note-0000001947257714"/>
#       <note dur="16" oct="5" pname="b" xml:id="note-0000002057102565"/>
#      </beam>
#      <beam xml:id="beam-0000000824062198">
#       <note dur="8" oct="5" pname="a" xml:id="note-0000001383576902"/>
#       <note dur="8" oct="5" pname="g" xml:id="note-0000000891322283"/>
#      </beam>
# ...
